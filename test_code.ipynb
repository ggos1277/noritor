# %% [markdown]
# <a href="https://colab.research.google.com/github/ggos1277/noritor/blob/master/test_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function

import pandas as pd
pd.__version__
# Out:
# '0.25.3'
